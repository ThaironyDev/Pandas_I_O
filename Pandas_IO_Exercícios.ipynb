# %% [markdown]
# <a href="https://colab.research.google.com/github/ThaironyDev/Pandas_OI/blob/main/Pandas_IO_Exerc%C3%ADcios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Para saber mais: erro de encoding - Como resolver?

# %% [markdown]
# Quando tentamos abrir um arquivo que foi salvo com um tipo de formatação de caracteres diferente do padrão universal UTF-8, podemos ter um erro de encoding. Para resolver essa questão, podemos usar a biblioteca chardet para detectar o encoding de um arquivo. Podemos ver que o tipo de codificação do arquivo é 'ascii' que por sua vez é compatível com a 'UTF-8'.

# %%
import chardet
import requests
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/superstore_data_ponto_virgula.csv'
response = requests.get(url)
if response.status_code == 200:
  content = response.content
  encoding_info = chardet.detect(content)
  print(encoding_info)
else:
  print('Falha ao obter o aquivo da URL.')
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# ##Desafio: lendo dados com vários parâmetros

# %%
import chardet, requests, csv, pandas as pd

# %% [markdown]
# >Verificando a codificação do arquivo.

# %%
response = requests.get(url)
if response.status_code == 200:
  content = response.content
  info_encoding = chardet.detect(content)
  print(info_encoding)
else:
  print('Falha ao obter o aquivo da URL.')
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# >Verificando se o arquivo é separado por virgula.

# %%
encoding = info_encoding['encoding']
sniffer = csv.Sniffer()
dialect = sniffer.sniff(content.decode(encoding))
separador = dialect.delimiter
df = pd.read_csv(url, delimiter=separador, encoding=encoding)

print(f"Delimitador detectado: '{separador}'")
# Out:
# Delimitador detectado: ';'

# %% [markdown]
# >Desconsiderando as 3 primeiras linhas.

# %%
df = pd.read_csv(url, skiprows=3, sep=separador)
df.head()
# Out:
#    10476  1958  Graduation   Married    67267  0  1  5/13/2014  0.1  134  ...  \
# 0   1386  1967  Graduation  Together  32474.0  1  1  11/5/2014    0   10  ...
# 1   5371  1989  Graduation    Single  21474.0  1  0   8/4/2014    0    6  ...
# 2   7348  1958         PhD    Single  71691.0  0  0  3/17/2014    0  336  ...
# 3   4073  1954    2n Cycle   Married  63564.0  0  0  1/29/2014    0  769  ...
# 4   1991  1967  Graduation  Together  44931.0  0  1  1/18/2014    0   78  ...
#
#     15   2  30  1.1   3  2.1  5  2.2  0.2  0.3
# 0    0   0   0    1   1    0  2    7    0    0
# 1   11   0  34    2   3    1  2    7    1    0
# 2  240  32  43    1   4    7  5    2    1    0
# 3   15  34  65    1  10   10  7    6    1    0
# 4    0   0   7    1   2    1  3    5    0    0
#
# [5 rows x 22 columns]

# %%
df = pd.read_csv(url, skipfooter=9, engine='python', sep=separador)
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# ## Desafio: lendo dados de outro link

# %% [markdown]
# >Neste trecho dividimos nosso código em 3 partes além de importar a biblioteca do pandas.
# de posse da string que pertence a planilha que está no goolge planilhas podemos instanciar as variáveis sheet_id e url usando os parâmetros necessários de acesso a API na variável param.

# %%
import pandas as pd
'https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit?usp=sharing'
sheet_id = '1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'
param = '/gviz/tq?tqx=out:csv&sheet'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}{param}'

# %% [markdown]
# >Efetuamos a leitura do arquivo.

# %%
emissoes_carbono_mundo = pd.read_csv(url)

# %% [markdown]
# >Salvamos no formato csv.

# %%
emissoes_carbono_mundo.to_csv('emissoes_carbono_mundo.csv', index=False, sep=',')

# %% [markdown]
# >Confirmamos se o arquivo foi salvo corretamente.

# %%
pd.read_csv('emissoes_carbono_mundo.csv').head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# ...

# %% [markdown]
# ##Desafio: normalizando o JSON obtido na API

# %% [markdown]
# >Para saber mais: obtendo arquivos JSON de APIs
#
# ---
# Primeiramente acessamos os dados via requisição HTTP para a API da fruityvice.com. Depois, verificamos o status da requisição. Em seguida, instanciamos o conteúdo de interesse em uma variável. Usando a biblioteca json, carregamos esses dados que estão em formato JSON para um formato de dicionário Python. Por fim, usando o método pd.json_normalize, criamos um DataFrame normalizado a partir deste dicionário e apresentamos suas 5 primeiras linhas.

# %%
import requests, json, pandas as pd

# %%
url = 'https://fruityvice.com/api/fruit/all'
response = requests.get(url)
response.status_code
content = response.content
dados_dict = json.loads(content)
dados_frutas = pd.json_normalize(dados_dict)
dados_frutas.head()
# Out:
#          name  id      family         order      genus  nutritions.calories  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros                   81
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria                   29
# 2      Banana   1    Musaceae  Zingiberales       Musa                   96
# 3      Tomato   5  Solanaceae     Solanales    Solanum                   74
# 4        Pear   4    Rosaceae       Rosales      Pyrus                   57
#
#    nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 0             0.0              18.0                      18.0
# 1             0.4               5.4                       5.5
# 2             0.2              17.2                      22.0
# 3             0.2               2.6                       3.9
# 4             0.1              10.0                      15.0
#
#    nutritions.protein
# 0                 0.0
# 1                 0.8
# 2                 1.0
# 3                 0.9
# ...

# %% [markdown]
# ##Desafio: lendo uma tabela de uma página web

# %% [markdown]
# > Neste caso após importar as libs de interesse realizamos a requisição http, depois de posse do conteúdo html instanciamos a variável dados_habitantes com a tabela de interesse usando o método pd.read_html()[], por fim eliminamos a coluna adicional correspondentes aos índices do arquivo e apresentamos as 5 primeiras linhas.

# %%
import requests, pandas as pd
url = 'https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o'
response = requests.get(url)
response.status_code
content = response.content
dados_habitantes = pd.read_html(content)[0]
dados_habitantes.drop('Unnamed: 0', axis=1, inplace=True)
dados_habitantes.head()
# Out:
#   Posição País (ou território dependente) Estimativa da ONU  Data  \
# 0       1                           Índia     1 429 921 746  2023
# 1       2                           China     1 426 391 281  2023
# 2       3                  Estados Unidos       339 987 103  2023
# 3       4                       Indonésia       277 184 719  2023
# 4       5                       Paquistão       240 215 932  2023
#
#    Estimativa Oficial
# 0  Estimativa oficial
# 1       Censo oficial
# 2       Censo oficial
# 3  Estimativa oficial
# 4  Estimativa oficial

# %% [markdown]
# ##Desafio: manipulando um banco de dados

# %% [markdown]
# >Para garantir a conpatibilidade dos comandos vamos usar uma versão do sqlalchemy inferior a 2. Por tanto o primeiro passo é prepararo o ambiente.

# %%
# !pip install --upgrade 'sqlalchemy<2'
import sqlalchemy, pandas as pd
sqlalchemy.__version__
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.22
#     Uninstalling SQLAlchemy-2.0.22:
#       Successfully uninstalled SQLAlchemy-2.0.22
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.50 which is incompatible.
# ...
# '1.4.50'

# %% [markdown]
# >Usando as ferramentas do sqlalchemy para criação e gestão do banco de dados.

# %%
from sqlalchemy import create_engine, inspect

# %% [markdown]
# >Criando um banco de dados local.
#
# ---
#
# >Criando o nosso motor de conexão com o banco de dados para isso vamos usar a função create_engine() passando uma string que informa qual SGBD vamos usar e onde será alocada.
#
# ---
#
# 'sqlite -> SGBD' eo ':///:mermory:' diz respeito a uma espaço na memória local.

# %%
engine = create_engine('sqlite:///:memory')

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'
dados = pd.read_csv(url)
dados.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %% [markdown]
# >Verificando se a tabela foi criada com exito.

# %%
inspetor = inspect(engine)
inspetor.get_table_names() # Exibe os nomes das tabelas que constam no banco de dados.
# Out:
# ['clientes']

# %% [markdown]
# >Fazendo uma consulta ao banco de dados.

# %%
query = 'SELECT * FROM clientes'
pd.read_sql(query, con=engine).head()
#ou
pd.read_sql_table('clientes', engine).head()
#Note que na primeira temos uma consulta SQL e na segunda temos um metodo onde informamos a tabela que queremos visualizar.
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# ...

# %% [markdown]
# >Atualizar o registro do cliente de ID 6840104 que teve o rendimento anual alterado para 300000.

# %%
query = 'UPDATE clientes SET Rendimento_anual = 300000 WHERE ID_Cliente == 6840104'
with engine.connect() as conn:
  conn.execute(query)
query = 'SELECT *  FROM clientes WHERE ID_Cliente == 6840104'
pd.read_sql(query, con=engine).head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0     6840104     62      Ensino médio   Divorciado                1
#
#   Categoria_de_renda Ocupacao  Anos_empregado  Rendimento_anual  Tem_carro  \
# 0        Pensionista    Outro               0          300000.0          0
#
#                     Moradia
# 0  Casa/apartamento próprio

# %% [markdown]
# >Excluir o registro do cliente de ID 5008809, pois essa pessoa não possui mais conta na instituição financeira.

# %%
query = 'DELETE FROM clientes WHERE ID_Cliente = 5008809'
with engine.connect() as conn:
  conn.execute(query)
pd.read_sql_table('clientes', engine).head(6)
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008810     52      Ensino médio       Solteiro                1
# 5     5008811     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
# ...

# %% [markdown]
# >Criar um novo registro de cliente seguindo as especificações abaixo:
#
# ---
#
#
# * ID_Cliente: 6850985
# * Idade: 33
# * Grau_escolaridade: Doutorado
# * Estado_civil: Solteiro
# * Tamanho_familia: 1
# * Categoria_de_renda: Empregado
# * Ocupacao: TI
# * Anos_empregado: 2
# * Rendimento_anual: 290000
# * Tem_carro: 0
# * Moradia: Casa/apartamento próprio

# %%
# @title
query = 'INSERT INTO clientes (ID_Cliente, Idade, Grau_escolaridade, Estado_civil, Tamanho_familia, ' + \
        'Categoria_de_renda, Ocupacao, Anos_empregado, Rendimento_anual, Tem_carro, Moradia) ' + \
        'VALUES (6850985, 33, "Doutorado", "Solteiro", 1, "Empregado", "TI", 2, 290000, 0, "Casa/Apartamento próprio")'

with engine.connect() as conn:
  conn.execute(query)
query = 'SELECT * FROM clientes WHERE ID_Cliente = 6850985'
pd.read_sql(query, con=engine)
# Out:
#    ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0     6850985     33         Doutorado     Solteiro                1
#
#   Categoria_de_renda Ocupacao  Anos_empregado  Rendimento_anual  Tem_carro  \
# 0          Empregado       TI               2          290000.0          0
#
#                     Moradia
# 0  Casa/Apartamento próprio
